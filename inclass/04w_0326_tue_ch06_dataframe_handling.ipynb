# %% [markdown]
# <a href="https://colab.research.google.com/github/simsoohyeon/2024-1-my-BDA/blob/main/inclass/04w_0326_tue_ch06_dataframe_handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**빅데이터분석프로그래밍**

# %% [markdown]
# ## 파이썬 설치 확인

# %%
import site
site.getsitepackages()
# Out:
# ['/usr/local/lib/python3.10/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/lib/python3.10/dist-packages']

# %%
import sys
import pandas as pd
import numpy as np
import seaborn as sns

print(sys.version)
print(pd.__version__)
print(np.__version__)
print(sns.__version__)
# Out:
# 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# 1.5.3
# 1.25.2
# 0.13.1

# %% [markdown]
# ## 코랩에서 한글처리

# %%
# !pip install koreanize_matplotlib
# Out:
# Collecting koreanize_matplotlib
#   Downloading koreanize_matplotlib-0.1.1-py3-none-any.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 16.3 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from koreanize_matplotlib) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize_matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize_matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize_matplotlib) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize_matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize_matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize_matplotlib) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize_matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize_matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize_matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->koreanize_matplotlib) (1.16.0)
# Installing collected packages: koreanize_matplotlib
# Successfully installed koreanize_matplotlib-0.1.1

# %%
# 그램 선명하게
# %config InlineBackend_matplotilb
# Out:
# UsageError: Invalid config statement: 'InlineBackend_matplotilb', should be `Class.trait = value`.

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib

plt.plot([-10,5,-3,1])
plt.title('그래프제목')
plt.xlabel('직선')
plt.show()

# %% [markdown]
# ## 수업에서 사용할 데이터를 다음 깃에서 복사
# - http://github.com/ai7dnn/data.git
#   ## 수업에서 파일 사용시
#     - 현재하부폴더: data
#     - 파일: data/파일이름

# %%
# !git clone http://github.com/ai7dnn/data.git
# Out:
# Cloning into 'data'...
# warning: redirecting to https://github.com/ai7dnn/data.git/
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 24 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (24/24), 4.00 MiB | 6.46 MiB/s, done.

# %%
import pandas as pd

exam = pd.read_csv('data/exam.csv')
exam.head()
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65

# %%
exam.sample() ## ()괄호 안의 숫자는 몇 개의 예시를 나타낼지 결정
# Out:
#     id  nclass  math  english  science
# 14  15       4    75       56       78

# %%
exam.query('nclass == 1')
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58

# %%
exam[exam['nclass'] ==1]
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58

# %%
exam['nclass'] ==1
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: nclass, dtype: bool

# %%
# 2반인 경우만 추출
exam.query('nclass == 2')
# Out:
#    id  nclass  math  english  science
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25

# %%
exam.query('math > 50') # 수학 점수가 50을 초과한 경우
# Out:
#     id  nclass  math  english  science
# 1    2       1    60       97       60
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 10  11       3    65       65       65
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
# 영어점수가 80점 이하
exam.query('english < = 80')
# Out:
#     id  nclass  math  english  science
# 4    5       2    25       80       65
# 7    8       2    90       78       25
# 10  11       3    65       65       65
# 14  15       4    75       56       78
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87

# %%
# 1반이면서 수학 점수가 50점 이상인 경우
exam.query('nclass == 1 & math >= 50')
# exam.query('(nclass == 1) & (math >= 50)') ()로 연결해도 됨!!
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60

# %%
# 2반이면서 영어 점수가 80점 이상인 경우
exam.query('nclass ==2 & english >= 80')
# Out:
#    id  nclass  math  english  science
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45

# %%
# 수학 90이상 이거나 영어 90이상인 경우
exam.query('math>=90 | english>=90')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 12  13       4    46       98       65
# 15  16       4    58       98       65

# %%
#1,3,5반에 해당하면 추출
# 원시적 방법 exam.query('nclass==1 | nclass==3 | nclass=5')
exam.query('nclass in[1,3,5]') # 시험 예상
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam[exam['nclass'].isin([1,3,5])] # isin 메소드 시험 예상!!!
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam['nclass'] # 결과의 자료형: series
# Out:
# 0     1
# 1     1
# 2     1
# 3     1
# 4     2
# 5     2
# 6     2
# 7     2
# 8     3
# 9     3
# 10    3
# 11    3
# 12    4
# 13    4
# 14    4
# 15    4
# 16    5
# 17    5
# 18    5
# 19    5
# Name: nclass, dtype: int64

# %%
type(exam['nclass'])
# Out:
# pandas.core.series.Series

# %%
exam[['nclass']] # 자료형: 데이터프레임
# Out:
#     nclass
# 0        1
# 1        1
# 2        1
# 3        1
# 4        2
# 5        2
# 6        2
# 7        2
# 8        3
# 9        3
# 10       3
# 11       3
# 12       4
# 13       4
# 14       4
# 15       4
# 16       5
# 17       5
# 18       5
# 19       5
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['nclass'].plot(kind='hist', bins=20, title='nclass')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['nclass']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'nclass'}, axis=1)
#               .sort_values('nclass', ascending=True))
#   xs = counted['nclass']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_1.sort_values('nclass', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('nclass')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2['nclass'].plot(kind='line', figsize=(8, 4), title='nclass')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
type(exam[['nclass']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## 추출한 행으로 데이터 만들기

# %%
# nclass가 1인 행 추출해 nclass1에 할당
nclass1 = exam.query('nclass == 1')

# nclass가 2인 행 추출해 nclass2에 할당
nclass2 = exam.query('nclass == 2')

# %%
nclass1['math'].mean()
# Out:
# 46.25

# %%
nclass1['math'].sum()
# Out:
# 185

# %%
nclass1.math.sum()
# Out:
# 185

# %%
# nclass가 1인 행 추출해 nclass1에 할당
nclass1 = exam[exam.nclass == 1]

# nclass가 2인 행 추출해 nclass2에 할당
nclass2 = exam[exam.nclass == 2]

# %%
# 2반 과학 점수 평균 구하기
nclass2.science.mean()
# Out:
# 58.25

# %% [markdown]
# ## 문자변수를 이용해 조건에 맞는 행 추출하기

# %%
df = pd.DataFrame({'sex'    :['F','M','F','M'],
                   'country':['Korea','China','Japan','USA']})
df
# Out:
#   sex country
# 0   F   Korea
# 1   M   China
# 2   F   Japan
# 3   M     USA

# %%
# 전체 조건에 작은따옴표, 추출할 문자에 큰따옴표 사용
df.query('sex == "F" & country == "Korea"')
# Out:
#   sex country
# 0   F   Korea

# %% [markdown]
# ## 알아두면 좋은 외부변수이용해 추출하기

# %%
var = 2
exam.query('nclass==@var')
# Out:
#    id  nclass  math  english  science
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25

# %%
exam[exam.nclass==var]
# Out:
#    id  nclass  math  english  science
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25

# %% [markdown]
# |논리연산자|기능|
# |:----------:|-------|
# |<|작다|
# |-|빼기|
# |*|곱하기|
# |**|제곱|
# |/|나누기|
# |//|나눗셈의 몫|
# |%|나눗셈의 나머지|

# %%
http://pandas.pydata.org
http://seaborn.pydata.org

# %%
df = pd.DataFrame({'num_legs': [2, 4], 'num_wings': [2, 0]},
                  index=['falcon', 'dog'])
df
# Out:
#         num_legs  num_wings
# falcon         2          2
# dog            4          0

# %%
df.isin([0]) # list나 dict 형태
# Out:
#         num_legs  num_wings
# falcon     False      False
# dog        False       True

# %%
df.isin([0, 2])
# Out:
#         num_legs  num_wings
# falcon      True       True
# dog        False       True

# %%
~df.isin([0, 2])
df
# Out:
#         num_legs  num_wings
# falcon         2          2
# dog            4          0

# %%
df.isin({'num_wings': [0, 3]})
# Out:
#         num_legs  num_wings
# falcon     False      False
# dog        False       True

# %% [markdown]
# 값이 Series(시리즈) 또는 DataFrame(데이터 프레임)인 경우 인덱스와 열이 일치해야 합니다. 'falcon(팔콘)'은 다른 부분의 다리 수를 기준으로 일치하지 않습니다.

# %%
other = pd.DataFrame({'num_legs': [8, 3], 'num_wings': [0, 2]},
                     index=['spider', 'falcon'])
other
# Out:
#         num_legs  num_wings
# spider         8          0
# falcon         3          2

# %%
df.isin(other)
# Out:
#         num_legs  num_wings
# falcon     False       True
# dog        False      False

# %% [markdown]
# ## 필요한 변수만 추출하기

# %%
exam['math']
# Out:
# 0     50
# 1     60
# 2     45
# 3     30
# 4     25
# 5     50
# 6     80
# 7     90
# 8     20
# 9     50
# 10    65
# 11    45
# 12    46
# 13    48
# 14    75
# 15    58
# 16    65
# 17    80
# 18    89
# 19    78
# Name: math, dtype: int64

# %%
exam['english']
# Out:
# 0     98
# 1     97
# 2     86
# 3     98
# 4     80
# 5     89
# 6     90
# 7     78
# 8     98
# 9     98
# 10    65
# 11    85
# 12    98
# 13    87
# 14    56
# 15    98
# 16    68
# 17    78
# 18    68
# 19    83
# Name: english, dtype: int64

# %%
exam[['english']]
# Out:
#     english
# 0        98
# 1        97
# 2        86
# 3        98
# 4        80
# 5        89
# 6        90
# 7        78
# 8        98
# 9        98
# 10       65
# 11       85
# 12       98
# 13       87
# 14       56
# 15       98
# 16       68
# 17       78
# 18       68
# 19       83

# %%
exam.columns[1:3]
# Out:
# Index(['nclass', 'math'], dtype='object')

# %%
exam[exam.columns[1:3]]
# Out:
#     nclass  math
# 0        1    50
# 1        1    60
# 2        1    45
# 3        1    30
# 4        2    25
# 5        2    50
# 6        2    80
# 7        2    90
# 8        3    20
# 9        3    50
# 10       3    65
# 11       3    45
# 12       4    46
# 13       4    48
# 14       4    75
# 15       4    58
# 16       5    65
# 17       5    80
# 18       5    89
# 19       5    78

# %% [markdown]
# ### 행과 변수(열) 제거하기

# %%
exam.sample(3)
# Out:
#    id  nclass  math  english  science
# 1   2       1    60       97       60
# 6   7       2    80       90       45
# 7   8       2    90       78       25

# %%
exam.drop(1) ## index1인 행 사라짐
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop([1,5])
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.sample(3)
# Out:
#     id  nclass  math  english  science
# 1    2       1    60       97       60
# 11  12       3    45       85       32
# 10  11       3    65       65       65

# %%
exam.drop(labels=2,axis=0)
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop(labels='nclass',axis=1)
# Out:
#     id  math  english  science
# 0    1    50       98       50
# 1    2    60       97       60
# 2    3    45       86       78
# 3    4    30       98       58
# 4    5    25       80       65
# 5    6    50       89       98
# 6    7    80       90       45
# 7    8    90       78       25
# 8    9    20       98       15
# 9   10    50       98       45
# 10  11    65       65       65
# 11  12    45       85       32
# 12  13    46       98       65
# 13  14    48       87       12
# 14  15    75       56       78
# 15  16    58       98       65
# 16  17    65       68       98
# 17  18    80       78       90
# 18  19    89       68       87
# 19  20    78       83       58

# %%
exam.drop(['nclass', 'english'], axis=1) # 여러 열 삭제
# Out:
#     id  math  science
# 0    1    50       50
# 1    2    60       60
# 2    3    45       78
# 3    4    30       58
# 4    5    25       65
# 5    6    50       98
# 6    7    80       45
# 7    8    90       25
# 8    9    20       15
# 9   10    50       45
# 10  11    65       65
# 11  12    45       32
# 12  13    46       65
# 13  14    48       12
# 14  15    75       78
# 15  16    58       65
# 16  17    65       98
# 17  18    80       90
# 18  19    89       87
# 19  20    78       58

# %%
exam.drop(columns='math')
# Out:
#     id  nclass  english  science
# 0    1       1       98       50
# 1    2       1       97       60
# 2    3       1       86       78
# 3    4       1       98       58
# 4    5       2       80       65
# 5    6       2       89       98
# 6    7       2       90       45
# 7    8       2       78       25
# 8    9       3       98       15
# 9   10       3       98       45
# 10  11       3       65       65
# 11  12       3       85       32
# 12  13       4       98       65
# 13  14       4       87       12
# 14  15       4       56       78
# 15  16       4       98       65
# 16  17       5       68       98
# 17  18       5       78       90
# 18  19       5       68       87
# 19  20       5       83       58

# %%
exam.drop(columns=['math', 'science'])
# Out:
#     id  nclass  english
# 0    1       1       98
# 1    2       1       97
# 2    3       1       86
# 3    4       1       98
# 4    5       2       80
# 5    6       2       89
# 6    7       2       90
# 7    8       2       78
# 8    9       3       98
# 9   10       3       98
# 10  11       3       65
# 11  12       3       85
# 12  13       4       98
# 13  14       4       87
# 14  15       4       56
# 15  16       4       98
# 16  17       5       68
# 17  18       5       78
# 18  19       5       68
# 19  20       5       83

# %% [markdown]
# ## pandas 함수 조합하기

# %%
# nclass가 1인 행만 추출한 다음 english 추출
exam.query('nclass==1')['english']
# Out:
# 0    98
# 1    97
# 2    86
# 3    98
# Name: english, dtype: int64

# %%
# 수학이 50이상인 행만 추출한 다음 id, math추출
exam.query('math>=50')[['id','math']].sample(3)
# Out:
#     id  math
# 16  17    65
# 7    8    90
# 14  15    75

# %%
exam.query('math>=50')[['id','math']].sample(frac=.4) # frac % 결정!!
# Out:
#     id  math
# 15  16    58
# 0    1    50
# 6    7    80
# 10  11    65
# 5    6    50

# %% [markdown]
# ## 가독성있게 코드 줄 바꾸기

# %%
# math가 50이상
# id,math 추출
# 앞부분 10행 추출
exam.query('math >= 50')[['id','math']].head(10)
# Out:
#     id  math
# 0    1    50
# 1    2    60
# 5    6    50
# 6    7    80
# 7    8    90
# 9   10    50
# 10  11    65
# 14  15    75
# 15  16    58
# 16  17    65

# %%
exam.query('math >= 50') \
    [['id', 'math']] \
    .head(10)
# Out:
#     id  math
# 0    1    50
# 1    2    60
# 5    6    50
# 6    7    80
# 7    8    90
# 9   10    50
# 10  11    65
# 14  15    75
# 15  16    58
# 16  17    65

# %% [markdown]
# ## 순서대로 정렬하기

# %%
exam.sort_values('math')
# Out:
#     id  nclass  math  english  science
# 8    9       3    20       98       15
# 4    5       2    25       80       65
# 3    4       1    30       98       58
# 2    3       1    45       86       78
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 0    1       1    50       98       50
# 9   10       3    50       98       45
# 5    6       2    50       89       98
# 15  16       4    58       98       65
# 1    2       1    60       97       60
# 10  11       3    65       65       65
# 16  17       5    65       68       98
# 14  15       4    75       56       78
# 19  20       5    78       83       58
# 6    7       2    80       90       45
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 7    8       2    90       78       25

# %%
# math 오름차순 정렬
exam.sort_values('math')
# Out:
#     id  nclass  math  english  science
# 8    9       3    20       98       15
# 4    5       2    25       80       65
# 3    4       1    30       98       58
# 2    3       1    45       86       78
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 0    1       1    50       98       50
# 9   10       3    50       98       45
# 5    6       2    50       89       98
# 15  16       4    58       98       65
# 1    2       1    60       97       60
# 10  11       3    65       65       65
# 16  17       5    65       68       98
# 14  15       4    75       56       78
# 19  20       5    78       83       58
# 6    7       2    80       90       45
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 7    8       2    90       78       25

# %%
# math 내림차순 정렬
exam.sort_value('math', ascending=false)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-100-050b410509b6> in <cell line: 2>()
#       1 # math 내림차순 정렬
# ----> 2 exam.sort_value('math', ascending=false)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'sort_value'

# %%
# nclass, math 오름차순 정렬
exam.sort_values(['nclass', 'math'])
# Out:
#     id  nclass  math  english  science
# 3    4       1    30       98       58
# 2    3       1    45       86       78
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 11  12       3    45       85       32
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 15  16       4    58       98       65
# 14  15       4    75       56       78
# 16  17       5    65       68       98
# 19  20       5    78       83       58
# 17  18       5    80       78       90
# 18  19       5    89       68       87

# %%
# nclass 오름차순, math 내림차순 정렬
exam.sort_values(['nclass', 'math'], ascending = [True, False])
# Out:
#     id  nclass  math  english  science
# 1    2       1    60       97       60
# 0    1       1    50       98       50
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 7    8       2    90       78       25
# 6    7       2    80       90       45
# 5    6       2    50       89       98
# 4    5       2    25       80       65
# 10  11       3    65       65       65
# 9   10       3    50       98       45
# 11  12       3    45       85       32
# 8    9       3    20       98       15
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 13  14       4    48       87       12
# 12  13       4    46       98       65
# 18  19       5    89       68       87
# 17  18       5    80       78       90
# 19  20       5    78       83       58
# 16  17       5    65       68       98

# %% [markdown]
# ## 파생변수 추가하기

# %%
# total 변수 추가
exam.assign(total=exam['math']+exam['english']+exam['science'])
# Out:
#     id  nclass  math  english  science  total
# 0    1       1    50       98       50    198
# 1    2       1    60       97       60    217
# 2    3       1    45       86       78    209
# 3    4       1    30       98       58    186
# 4    5       2    25       80       65    170
# 5    6       2    50       89       98    237
# 6    7       2    80       90       45    215
# 7    8       2    90       78       25    193
# 8    9       3    20       98       15    133
# 9   10       3    50       98       45    193
# 10  11       3    65       65       65    195
# 11  12       3    45       85       32    162
# 12  13       4    46       98       65    209
# 13  14       4    48       87       12    147
# 14  15       4    75       56       78    209
# 15  16       4    58       98       65    221
# 16  17       5    65       68       98    231
# 17  18       5    80       78       90    248
# 18  19       5    89       68       87    244
# 19  20       5    78       83       58    219

# %%
exam.sample(4)
# Out:
#    id  nclass  math  english  science
# 8   9       3    20       98       15
# 2   3       1    45       86       78
# 4   5       2    25       80       65
# 5   6       2    50       89       98

# %%
# total 변수 추가
exam['total']=exam['math']+exam['english']+exam['science']
exam.sample(3)
# Out:
#     id  nclass  math  english  science  total
# 10  11       3    65       65       65    195
# 19  20       5    78       83       58    219
# 17  18       5    80       78       90    248

# %% [markdown]
# ## 여러 파생변수 한 번에 추가하기

# %%
exam.assign(total=exam['math']+exam['english']+exam['science'], # total추가
            mean=exam['math']+exam['english']+exam['science']/3) # mean 추가
# Out:
#     id  nclass  math  english  science  total        mean
# 0    1       1    50       98       50    198  164.666667
# 1    2       1    60       97       60    217  177.000000
# 2    3       1    45       86       78    209  157.000000
# 3    4       1    30       98       58    186  147.333333
# 4    5       2    25       80       65    170  126.666667
# 5    6       2    50       89       98    237  171.666667
# 6    7       2    80       90       45    215  185.000000
# 7    8       2    90       78       25    193  176.333333
# 8    9       3    20       98       15    133  123.000000
# 9   10       3    50       98       45    193  163.000000
# 10  11       3    65       65       65    195  151.666667
# 11  12       3    45       85       32    162  140.666667
# 12  13       4    46       98       65    209  165.666667
# 13  14       4    48       87       12    147  139.000000
# 14  15       4    75       56       78    209  157.000000
# 15  16       4    58       98       65    221  177.666667
# 16  17       5    65       68       98    231  165.666667
# 17  18       5    80       78       90    248  188.000000
# 18  19       5    89       68       87    244  186.000000
# 19  20       5    78       83       58    219  180.333333

# %% [markdown]
# ## df.assign()에 np.where() 적용하기

# %%
import pandas as pd
exam=pd.read_csv('data/exam.csv')

# %%
import numpy as np
exam.assign(test=np.where(exam['science']>=60,'pass','fail'))
# Out:
#     id  nclass  math  english  science  total  test
# 0    1       1    50       98       50    198  fail
# 1    2       1    60       97       60    217  pass
# 2    3       1    45       86       78    209  pass
# 3    4       1    30       98       58    186  fail
# 4    5       2    25       80       65    170  pass
# 5    6       2    50       89       98    237  pass
# 6    7       2    80       90       45    215  fail
# 7    8       2    90       78       25    193  fail
# 8    9       3    20       98       15    133  fail
# 9   10       3    50       98       45    193  fail
# 10  11       3    65       65       65    195  pass
# 11  12       3    45       85       32    162  fail
# 12  13       4    46       98       65    209  pass
# 13  14       4    48       87       12    147  fail
# 14  15       4    75       56       78    209  pass
# 15  16       4    58       98       65    221  pass
# 16  17       5    65       68       98    231  pass
# 17  18       5    80       78       90    248  pass
# 18  19       5    89       68       87    244  pass
# 19  20       5    78       83       58    219  fail

# %% [markdown]
# ## 추가한 변수를 'pandas'함수에 바로 활용하기

# %%
# total 변수 추가
# total 기준 정렬
exam.assign(total=exam['math']+exam['english']+exam['science']).sort_values('total')
# Out:
#     id  nclass  math  english  science  total
# 8    9       3    20       98       15    133
# 13  14       4    48       87       12    147
# 11  12       3    45       85       32    162
# 4    5       2    25       80       65    170
# 3    4       1    30       98       58    186
# 9   10       3    50       98       45    193
# 7    8       2    90       78       25    193
# 10  11       3    65       65       65    195
# 0    1       1    50       98       50    198
# 2    3       1    45       86       78    209
# 12  13       4    46       98       65    209
# 14  15       4    75       56       78    209
# 6    7       2    80       90       45    215
# 1    2       1    60       97       60    217
# 19  20       5    78       83       58    219
# 15  16       4    58       98       65    221
# 16  17       5    65       68       98    231
# 5    6       2    50       89       98    237
# 18  19       5    89       68       87    244
# 17  18       5    80       78       90    248

# %% [markdown]
# ### 'lambda' 이용해 데이터 프레임명 줄여쓰기

# %%
# 긴 데이터 프레임명 지정
long_name = pd.read_csv('data/exam.csv')

#long_name 직접 입력
long_name.assign(new = long_name['math'] + long_name['english'] + long_name['science'])
# Out:
#     id  nclass  math  english  science  new
# 0    1       1    50       98       50  198
# 1    2       1    60       97       60  217
# 2    3       1    45       86       78  209
# 3    4       1    30       98       58  186
# 4    5       2    25       80       65  170
# 5    6       2    50       89       98  237
# 6    7       2    80       90       45  215
# 7    8       2    90       78       25  193
# 8    9       3    20       98       15  133
# 9   10       3    50       98       45  193
# 10  11       3    65       65       65  195
# 11  12       3    45       85       32  162
# 12  13       4    46       98       65  209
# 13  14       4    48       87       12  147
# 14  15       4    75       56       78  209
# 15  16       4    58       98       65  221
# 16  17       5    65       68       98  231
# 17  18       5    80       78       90  248
# 18  19       5    89       68       87  244
# 19  20       5    78       83       58  219

# %%
(lambda x,y:x+y)(10,20)
# Out:
# 30

# %%
# long_name 대신 x 입력
long_name.assign(new = lambda x: x['math'] + x['english'] + x['science'])
# Out:
#     id  nclass  math  english  science  new
# 0    1       1    50       98       50  198
# 1    2       1    60       97       60  217
# 2    3       1    45       86       78  209
# 3    4       1    30       98       58  186
# 4    5       2    25       80       65  170
# 5    6       2    50       89       98  237
# 6    7       2    80       90       45  215
# 7    8       2    90       78       25  193
# 8    9       3    20       98       15  133
# 9   10       3    50       98       45  193
# 10  11       3    65       65       65  195
# 11  12       3    45       85       32  162
# 12  13       4    46       98       65  209
# 13  14       4    48       87       12  147
# 14  15       4    75       56       78  209
# 15  16       4    58       98       65  221
# 16  17       5    65       68       98  231
# 17  18       5    80       78       90  248
# 18  19       5    89       68       87  244
# 19  20       5    78       83       58  219

# %% [markdown]
# ### 앞에서 만든 변수를 활용해 다시 변수 만들기

# %%
import pandas as pd

exam = pd.read_csv('data/exam.csv')
exam.assign(total = exam['math'] + exam['english'] + exam['science'],
            mean  = lambda x: round(x['total'] / 3, 2))
# Out:
#     id  nclass  math  english  science  total   mean
# 0    1       1    50       98       50    198  66.00
# 1    2       1    60       97       60    217  72.33
# 2    3       1    45       86       78    209  69.67
# 3    4       1    30       98       58    186  62.00
# 4    5       2    25       80       65    170  56.67
# 5    6       2    50       89       98    237  79.00
# 6    7       2    80       90       45    215  71.67
# 7    8       2    90       78       25    193  64.33
# 8    9       3    20       98       15    133  44.33
# 9   10       3    50       98       45    193  64.33
# 10  11       3    65       65       65    195  65.00
# 11  12       3    45       85       32    162  54.00
# 12  13       4    46       98       65    209  69.67
# 13  14       4    48       87       12    147  49.00
# 14  15       4    75       56       78    209  69.67
# 15  16       4    58       98       65    221  73.67
# 16  17       5    65       68       98    231  77.00
# 17  18       5    80       78       90    248  82.67
# 18  19       5    89       68       87    244  81.33
# 19  20       5    78       83       58    219  73.00

# %%
data = 1.125456
round(data, 2) # 소수점 세자리에서 반올림해서 둘째자리까지 나타내는 역할
# Out:
# 1.13

# %%
exam.assign(total = lambda x: x['math'] + x['english'] + x['science'],
            mean  = lambda x: round(x['total'] / 3, 3))
# Out:
#     id  nclass  math  english  science  total    mean
# 0    1       1    50       98       50    198  66.000
# 1    2       1    60       97       60    217  72.333
# 2    3       1    45       86       78    209  69.667
# 3    4       1    30       98       58    186  62.000
# 4    5       2    25       80       65    170  56.667
# 5    6       2    50       89       98    237  79.000
# 6    7       2    80       90       45    215  71.667
# 7    8       2    90       78       25    193  64.333
# 8    9       3    20       98       15    133  44.333
# 9   10       3    50       98       45    193  64.333
# 10  11       3    65       65       65    195  65.000
# 11  12       3    45       85       32    162  54.000
# 12  13       4    46       98       65    209  69.667
# 13  14       4    48       87       12    147  49.000
# 14  15       4    75       56       78    209  69.667
# 15  16       4    58       98       65    221  73.667
# 16  17       5    65       68       98    231  77.000
# 17  18       5    80       78       90    248  82.667
# 18  19       5    89       68       87    244  81.333
# 19  20       5    78       83       58    219  73.000

# %% [markdown]
# #**학습내용요약**

# %%
# 1. 조건에 맞는 데이터만 추출하기
exam.query('english<=80')
# 여러 조건 동시 충족
exam.query('nclass==1 & math>=50')
# 여러 조건 중 하나 이상 충족
exam.query('math>=90|english>=90')
exam.query('nclass in [1,3,5]')
#2. 필요한 변수만 추출하기
exam['math'] # 한 변수 추출
exam[['nclass', 'math', 'english']] # 여러 변수 추출
exam.drop(columns='math') # 변수 제거
exam.drop(columns=['math', 'english']) # 여러 변수 제거
## 3. pandas 명령어 조합하기
exam.query('math >= 50')[['id', 'math']].head()


## 4. 순서대로 정렬하기
exam.sort_values('math')                     # 오름차순 정렬
exam.sort_values('math', ascending = False)  # 내림차순 정렬

# 여러 변수 기준 정렬
exam.sort_values(['nclass', 'math'], ascending = [True, False])


## 5. 파생변수 추가하기
exam.assign(total = exam['math'] + exam['english'] + exam['science'])

# 여러 파생변수 한 번에 추가하기
exam.assign(total = exam['math'] + exam['english'] + exam['science'],
            mean = (exam['math'] + exam['english'] + exam['science']) / 3)

# assign()에 np.where() 적용하기
exam.assign(test = np.where(exam['science'] >= 60, 'pass', 'fall'))

# 추가한 변수를 pandas 코드에 바로 활용하기
exam.assign(total = exam['math'] + exam['english'] + exam['science']) \
    .sort_values('total') \
    .head()
# Out:
#     id  nclass  math  english  science  total
# 8    9       3    20       98       15    133
# 13  14       4    48       87       12    147
# 11  12       3    45       85       32    162
# 4    5       2    25       80       65    170
# 3    4       1    30       98       58    186
